# %% [markdown]
# <a href="https://colab.research.google.com/github/monish-09/Anudip_work/blob/main/second_day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# function syntax
def fun_name(parameters):
  pass
# call the function
fun_name("hello")

# %%
# def sum_numbers(*args):
#   """Calculates the sum of an arbitrary number of arguments."""
#   total = 0
#   for num in args:
#     total += num
#   return total

# # Example usage:
# print(f"Sum of 1, 2, 3: {sum_numbers(1, 2, 3)}")
# print(f"Sum of 10, 20: {sum_numbers(10, 20)}")
# print(f"Sum of 5, 5, 5, 5: {sum_numbers(5, 5, 5, 5)}")
# print(f"Sum of number: {sum_numbers(1,5,2)}")

# %%
# write a programe to check a number of odd and even
def check_number(num):
    if (num%2 == 0):
        return f"the number {num} is even"
    else:
        return f"the number {num} is odd"

num = int(input("enter the number: "))
print(check_number(num))
# Out:
# enter the number: 56
# the number 56 is even
