# %% [markdown]
# <a href="https://colab.research.google.com/github/monish-09/Anudip_work/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("source.txt", "r") as src:
      with open("destination.txt", "w") as dest:
              content = src.read()
              dest.write(content)

              print("File copied successfully ✅")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_17912/2851847635.py in <cell line: 0>()
# ----> 1 with open("source.txt", "r") as src:
#       2       with open("destination.txt", "w") as dest:
#       3               content = src.read()
#       4               dest.write(content)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'source.txt'
